# %%
pip install auto-sklearn --user
# Out:
# Requirement already satisfied: auto-sklearn in /home/ubuntu/.local/lib/python3.8/site-packages (0.14.7)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.8/site-packages (from auto-sklearn) (60.9.3)
# Requirement already satisfied: pyrfr<0.9,>=0.8.1 in /home/ubuntu/.local/lib/python3.8/site-packages (from auto-sklearn) (0.8.3)
# Requirement already satisfied: pynisher<0.7,>=0.6.3 in /home/ubuntu/.local/lib/python3.8/site-packages (from auto-sklearn) (0.6.4)
# Requirement already satisfied: pandas>=1.0 in /opt/conda/lib/python3.8/site-packages (from auto-sklearn) (1.3.5)
# Requirement already satisfied: threadpoolctl in /opt/conda/lib/python3.8/site-packages (from auto-sklearn) (3.1.0)
# Requirement already satisfied: smac<1.3,>=1.2 in /home/ubuntu/.local/lib/python3.8/site-packages (from auto-sklearn) (1.2)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.8/site-packages (from auto-sklearn) (1.1.0)
# Requirement already satisfied: scipy>=1.7.0 in /opt/conda/lib/python3.8/site-packages (from auto-sklearn) (1.7.3)
# Requirement already satisfied: distro in /home/ubuntu/.local/lib/python3.8/site-packages (from auto-sklearn) (1.7.0)
# Requirement already satisfied: dask>=2021.12 in /home/ubuntu/.local/lib/python3.8/site-packages (from auto-sklearn) (2022.8.1)
# Requirement already satisfied: liac-arff in /home/ubuntu/.local/lib/python3.8/site-packages (from auto-sklearn) (2.5.0)
# Requirement already satisfied: distributed>=2012.12 in /home/ubuntu/.local/lib/python3.8/site-packages (from auto-sklearn) (2022.8.1)
# Requirement already satisfied: numpy>=1.9.0 in /opt/conda/lib/python3.8/site-packages (from auto-sklearn) (1.21.5)
# Requirement already satisfied: pyyaml in /home/ubuntu/.local/lib/python3.8/site-packages (from auto-sklearn) (6.0)
# Requirement already satisfied: scikit-learn<0.25.0,>=0.24.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from auto-sklearn) (0.24.2)
# Requirement already satisfied: ConfigSpace<0.5,>=0.4.21 in /home/ubuntu/.local/lib/python3.8/site-packages (from auto-sklearn) (0.4.21)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.8/site-packages (from auto-sklearn) (4.1.1)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.8/site-packages (from ConfigSpace<0.5,>=0.4.21->auto-sklearn) (3.0.7)
# Requirement already satisfied: cython in /home/ubuntu/.local/lib/python3.8/site-packages (from ConfigSpace<0.5,>=0.4.21->auto-sklearn) (0.29.32)
# Requirement already satisfied: toolz>=0.8.2 in /home/ubuntu/.local/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn) (0.12.0)
# Requirement already satisfied: fsspec>=0.6.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn) (2022.7.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn) (21.3)
# Requirement already satisfied: partd>=0.3.10 in /home/ubuntu/.local/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn) (1.3.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in /home/ubuntu/.local/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn) (2.1.0)
# Requirement already satisfied: zict>=0.1.3 in /home/ubuntu/.local/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn) (2.2.0)
# Requirement already satisfied: msgpack>=0.6.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn) (1.0.4)
# Requirement already satisfied: jinja2 in /home/ubuntu/.local/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn) (3.0.3)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /home/ubuntu/.local/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn) (2.4.0)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn) (1.26.6)
# Requirement already satisfied: locket>=1.0.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn) (1.0.0)
# Requirement already satisfied: psutil>=5.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn) (5.9.1)
# Requirement already satisfied: tornado<6.2,>=6.0.3 in /home/ubuntu/.local/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn) (6.1)
# Requirement already satisfied: tblib>=1.6.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn) (1.7.0)
# Requirement already satisfied: click>=6.6 in /home/ubuntu/.local/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn) (8.0.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.8/site-packages (from pandas>=1.0->auto-sklearn) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.8/site-packages (from pandas>=1.0->auto-sklearn) (2021.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=1.0->auto-sklearn) (1.16.0)
# Requirement already satisfied: emcee>=3.0.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from smac<1.3,>=1.2->auto-sklearn) (3.1.2)
# Requirement already satisfied: heapdict in /home/ubuntu/.local/lib/python3.8/site-packages (from zict>=0.1.3->distributed>=2012.12->auto-sklearn) (1.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from jinja2->distributed>=2012.12->auto-sklearn) (2.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pprint import pprint
import time

import autosklearn.classification
import sklearn.model_selection
import sklearn.datasets
import sklearn.metrics
import pandas as pd
import numpy as np
import subprocess

# %%
#load data from Domino project directory
#load and clean the data----------------------

#load data from Domino project directory
hd_data = pd.read_csv("./data/raw/heart.csv")

hd_data.info()
hd_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
X = hd_data.drop('target', axis=1)
y = hd_data.target 

X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, random_state=1)

# %%
# %%time

scorer = autosklearn.metrics.log_loss

automl = autosklearn.classification.AutoSklearnClassifier(
    time_left_for_this_task=120,
    per_run_time_limit=30,
    ensemble_nbest = 5,
    resampling_strategy= 'cv',
    resampling_strategy_arguments = {'folds': 5},
    seed = 42,
    metric=scorer,
    scoring_functions = [autosklearn.metrics.log_loss,
                         autosklearn.metrics.roc_auc,
                         autosklearn.metrics.f1],
    tmp_folder='/tmp/autosklearn_classification_example_tmp',
)

automl.fit(X_train, y_train, dataset_name='heat_disease')
# Out:
# CPU times: user 1.24 s, sys: 523 ms, total: 1.76 s
# Wall time: 1min 55s
# AutoSklearnClassifier(ensemble_nbest=5, metric=log_loss, per_run_time_limit=30,
#                       resampling_strategy='cv',
#                       resampling_strategy_arguments={'folds': 5},
#                       scoring_functions=[log_loss, roc_auc, f1], seed=42,
#                       time_left_for_this_task=120,
#                       tmp_folder='/tmp/autosklearn_classification_example_tmp')

# %%
# automl.cv_results_['params'][0]

# %%
model_type = [clf['classifier:__choice__'] for clf in automl.cv_results_['params']]

automl_results = pd.DataFrame.from_dict(automl.cv_results_, orient='columns')

automl_results = automl_results[['mean_test_score', 'metric_log_loss',
                                 'metric_roc_auc', 'metric_f1',
                                 'mean_fit_time', 'params', 'rank_test_scores']]

automl_results['model_type'] = model_type
                                
automl_results = automl_results.sort_values(by='rank_test_scores', ascending=True)

automl_results.head(20)
# Out:
#     mean_test_score  metric_log_loss  metric_roc_auc  metric_f1  \
# 1      3.618882e-01         0.361888        0.922888   0.856108
# 10     3.637451e-01         0.363745        0.921684   0.857454
# 5      3.720230e-01         0.372023        0.922376   0.879645
# 0      3.742176e-01         0.374218        0.923139   0.879542
# 3      3.991232e-01         0.399123        0.910691   0.871436
# 6      4.438471e-01         0.443847        0.886554   0.855470
# 9      4.619792e-01         0.461979        0.880210   0.815541
# 7      5.718836e-01         0.571884        0.886542   0.826981
# 2      6.542025e-01         0.654202        0.907470   0.818240
# 8      6.894725e-01         0.689473        0.851437   0.830650
# 4      9.533739e-01         0.953374        0.835196   0.792416
# 11     2.147484e+09              NaN             NaN        NaN
#
#     mean_fit_time                                             params  \
# 1       19.384925  {'balancing:strategy': 'weighting', 'classifie...
# 10       6.907019  {'balancing:strategy': 'none', 'classifier:__c...
# 5        6.598950  {'balancing:strategy': 'none', 'classifier:__c...
# 0        6.494151  {'balancing:strategy': 'none', 'classifier:__c...
# 3        5.685201  {'balancing:strategy': 'none', 'classifier:__c...
# 6       24.465595  {'balancing:strategy': 'none', 'classifier:__c...
# 9        6.983931  {'balancing:strategy': 'none', 'classifier:__c...
# 7        7.949276  {'balancing:strategy': 'weighting', 'classifie...
# 2        7.313998  {'balancing:strategy': 'weighting', 'classifie...
# 8        8.105469  {'balancing:strategy': 'weighting', 'classifie...
# 4        4.399108  {'balancing:strategy': 'none', 'classifier:__c...
# 11       1.014444  {'balancing:strategy': 'weighting', 'classifie...
#
#     rank_test_scores         model_type
# 1                  1      random_forest
# 10                 2        extra_trees
# 5                  3      random_forest
# 0                  4      random_forest
# 3                  5  gradient_boosting
# 6                  6      random_forest
# 9                  7           adaboost
# 7                  8      random_forest
# 2                  9                mlp
# 8                 10                mlp
# 4                 11  gradient_boosting
# 11                12      random_forest

# %%
# %%time

scorer = autosklearn.metrics.log_loss

automl = autosklearn.classification.AutoSklearnClassifier(
    time_left_for_this_task=120,
    per_run_time_limit=30,
    ensemble_nbest = 5,
    resampling_strategy= 'cv',
    resampling_strategy_arguments = {'folds': 5},
    seed = 42,
    metric=scorer,
    scoring_functions = [autosklearn.metrics.log_loss,
                         autosklearn.metrics.roc_auc,
                         autosklearn.metrics.f1],
    tmp_folder='/tmp/autosklearn_classification_example_tmp',
    
    #turn on parallelization
    # n_jobs=4,
)

automl.fit(X_train, y_train, dataset_name='heat_disease')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# File <timed exec>:20, in <module>
#
# File ~/.local/lib/python3.8/site-packages/autosklearn/estimators.py:1045, in AutoSklearnClassifier.fit(self, X, y, X_test, y_test, feat_type, dataset_name)
#    1042 # remember target type for using in predict_proba later.
#    1043 self.target_type = target_type
# -> 1045 super().fit(
#    1046     X=X,
#    1047     y=y,
#    1048     X_test=X_test,
#    1049     y_test=y_test,
#    1050     feat_type=feat_type,
#    1051     dataset_name=dataset_name,
#    1052 )
#    1054 # After fit, a classifier is expected to define classes_
#    1055 # A list of class labels known to the classifier, mapping each label
#    1056 # to a numerical index used in the model representation our output.
#    1057 self.classes_ = self.automl_.InputValidator.target_validator.classes_
#
# File ~/.local/lib/python3.8/site-packages/autosklearn/estimators.py:375, in AutoSklearnEstimator.fit(self, **kwargs)
#     373 if self.automl_ is None:
#     374     self.automl_ = self.build_automl()
# --> 375 self.automl_.fit(load_models=self.load_models, **kwargs)
#     377 return self
#
# File ~/.local/lib/python3.8/site-packages/autosklearn/automl.py:2056, in AutoMLClassifier.fit(self, X, y, X_test, y_test, feat_type, dataset_name, only_return_configuration_space, load_models)
#    2045 def fit(
#    2046     self,
#    2047     X: SUPPORTED_FEAT_TYPES,
#    (...)
#    2054     load_models: bool = True,
#    2055 ):
# -> 2056     return super().fit(
#    2057         X, y,
#    2058         X_test=X_test,
#    2059         y_test=y_test,
#    2060         feat_type=feat_type,
#    2061         dataset_name=dataset_name,
#    2062         only_return_configuration_space=only_return_configuration_space,
#    2063         load_models=load_models,
#    2064         is_classification=True,
#    2065     )
#
# File ~/.local/lib/python3.8/site-packages/autosklearn/automl.py:614, in AutoML.fit(self, X, y, task, X_test, y_test, feat_type, dataset_name, only_return_configuration_space, load_models, is_classification)
#     611     dataset_name = str(uuid.uuid1(clock_seq=os.getpid()))
#     613 # Create the backend
# --> 614 self._backend = self._create_backend()
#     616 # By default try to use the TCP logging port or get a new port
#     617 self._logger_port = logging.handlers.DEFAULT_TCP_LOGGING_PORT
#
# File ~/.local/lib/python3.8/site-packages/autosklearn/automl.py:283, in AutoML._create_backend(self)
#     282 def _create_backend(self) -> Backend:
# --> 283     return create(
#     284         temporary_directory=self._temporary_directory,
#     285         output_directory=None,
#     286         prefix="auto-sklearn",
#     287         delete_tmp_folder_after_terminate=self._delete_tmp_folder_after_terminate,
#     288     )
#
# File ~/.local/lib/python3.8/site-packages/autosklearn/automl_common/common/utils/backend.py:35, in create(temporary_directory, output_directory, prefix, delete_tmp_folder_after_terminate, delete_output_folder_after_terminate)
#      28 def create(
#      29     temporary_directory: str,
#      30     output_directory: Optional[str],
#    (...)
#      33     delete_output_folder_after_terminate: bool = True,
#      34 ) -> "Backend":
# ---> 35     context = BackendContext(
#      36         temporary_directory,
#      37         output_directory,
#      38         delete_tmp_folder_after_terminate,
#      39         delete_output_folder_after_terminate,
#      40         prefix=prefix,
#      41     )
#      42     backend = Backend(context, prefix)
#      44     return backend
#
# File ~/.local/lib/python3.8/site-packages/autosklearn/automl_common/common/utils/backend.py:100, in BackendContext.__init__(self, temporary_directory, output_directory, delete_tmp_folder_after_terminate, delete_output_folder_after_terminate, prefix)
#      94 # Logging happens via PicklableClientLogger
#      95 # For this reason we need a port to communicate with the server
#      96 # When the backend is created, this port is not available
#      97 # When the port is available in the main process, we
#      98 # call the setup_logger with this port and update self.logger
#      99 self._logger = None  # type: Optional[PicklableClientLogger]
# --> 100 self.create_directories()
#
# File ~/.local/lib/python3.8/site-packages/autosklearn/automl_common/common/utils/backend.py:125, in BackendContext.create_directories(self, exist_ok)
#     121 def create_directories(self, exist_ok: bool = False) -> None:
#     122     # No Exception is raised if self.temporary_directory already exists.
#     123     # This allows to continue the search, also, an error will be raised if
#     124     # save_start_time is called which ensures two searches are not performed
# --> 125     os.makedirs(self.temporary_directory, exist_ok=exist_ok)
#     126     self._tmp_dir_created = True
#     128     if self.output_directory is not None:
#
# File /opt/conda/lib/python3.8/os.py:223, in makedirs(name, mode, exist_ok)
#     221         return
#     222 try:
# --> 223     mkdir(name, mode)
#     224 except OSError:
#     225     # Cannot rely on checking for EEXIST, since the operating system
#     226     # could give priority to other errors like EACCES or EROFS
#     227     if not exist_ok or not path.isdir(name):
#
# FileExistsError: [Errno 17] File exists: '/tmp/autosklearn_classification_example_tmp'
